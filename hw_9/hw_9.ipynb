# %% [markdown]
# # Урок 9. Инструменты разметки наборов данных

# %%
import pandas as pd
import re
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
import numpy as np
from sklearn.metrics import f1_score

# %% [markdown]
# ### Задание 1.
#
# Выберите датасет, который имеет отношение к вашей области интересов или исследований. Датасет должен содержать неструктурированные данные, требующие разметки для решения конкретной задачи, например, анализа настроений или распознавания именованных сущностей.

# %% [markdown]
# Выбранный датасет https://www.kaggle.com/datasets/kazanova/sentiment140

# %%
df = pd.read_csv('training_noemoticon.csv', encoding='ISO-8859-1', encoding_errors="ignore", header=None, names=['target', 'id', 'date', 'flag', 'user', 'text'])
df.head()
# Out:
#    target          id                          date      flag  \
# 0       0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1       0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2       0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3       0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4       0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
#
#               user                                               text
# 0  _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1    scotthamilton  is upset that he can't update his Facebook by ...
# 2         mattycus  @Kenichan I dived many times for the ball. Man...
# 3          ElleCTF    my whole body feels itchy and like its on fire
# 4           Karoli  @nationwideclass no, it's not behaving at all....

# %% [markdown]
# ### Задание 2.
#
# Выполните разметку на основе правил (rule-based labeling) на подмножестве выбранного датасета. Разработайте и реализуйте набор правил или условий, которые позволят автоматически присваивать метки данным на основе определенных шаблонов или критериев.

# %%
def label_text(tweet):
    if re.search(r'\b(хорошо|отлично|люблю|прекрасно|замечательно|супер|радостно|счастливо|великолепно|классно|приятно|good|great|love|wonderful|amazing|awesome|excellent|happy|superb|positive)\b', tweet, re.IGNORECASE):
        return 'Positive'
    elif re.search(r'\b(плохо|ненавижу|ужасно|отвратительно|грустно|печально|кошмарно|разочарован|ужасный|беда|bad|terrible|hate|awful|horrible|sad|worst|negative)\b', tweet, re.IGNORECASE):
        return 'Negative'
    else:
        return 'Neutral'
    
df2 = shuffle(df)

# df2, df2_unlabeled = train_test_split(df, train_size=0.2, random_state=42)
df2['sentiment'] = df2['text'].apply(label_text)

df2[df2['sentiment']!='Neutral'].head()
# Out:
#          target          id                          date      flag  \
# 933244        4  1791741842  Wed May 13 20:58:21 PDT 2009  NO_QUERY
# 1536633       4  2179342168  Mon Jun 15 08:58:36 PDT 2009  NO_QUERY
# 1372395       4  2051244577  Fri Jun 05 21:18:35 PDT 2009  NO_QUERY
# 1179930       4  1981821176  Sun May 31 09:57:43 PDT 2009  NO_QUERY
# 699794        0  2254558045  Sat Jun 20 09:56:09 PDT 2009  NO_QUERY
#
#                  user                                               text  \
# 933244   nasty_nazzle  Bath. It's amazing how weak in the knees she m...
# 1536633       LLinnda   @mitchelmusso wow, Mitchel. Good looking hair !
# 1372395    erinfinney  Just finished watching 'taken' -good movie to ...
# 1179930       ChaosAD  @hoppimike Hiya dude! Cheers for following me ...
# 699794    originalist  @gilldaniels I'm sorry  I feel bad!! But it wa...
#
#         sentiment
# 933244   Positive
# 1536633  Positive
# 1372395  Positive
# 1179930  Positive
# 699794   Negative

# %% [markdown]
# ### Задача 3.
#
# Выполните разметку вручную отдельного подмножества выбранного датасета с помощью выбранного вами инструмента разметки.

# %%
df_sample = df.sample(frac=0.0000625)
df_sample.to_csv('for_label_studio.csv', index=False)

# %%
df3 = pd.read_csv('project-1-at-2024-08-25-17-45-e6f66a9a.csv')
df3.head()
# Out:
#    annotation_id  annotator                   created_at  \
# 0              4          1  2024-08-25T14:34:09.025334Z
# 1              3          1  2024-08-25T14:34:07.189764Z
# 2              2          1  2024-08-25T14:34:04.178149Z
# 3              1          1  2024-08-25T14:34:00.211019Z
# 4              5          1  2024-08-25T14:34:33.544917Z
#
#                            date      flag          id  lead_time sentiment  \
# 0  Sat May 09 23:36:53 PDT 2009  NO_QUERY  1752964352     18.907   Neutral
# 1  Wed Jun 17 00:44:08 PDT 2009  NO_QUERY  2203868964      6.254  Negative
# 2  Sat May 30 16:12:12 PDT 2009  NO_QUERY  1975926613     10.454  Negative
# 3  Wed Jun 17 17:40:22 PDT 2009  NO_QUERY  2215098573      6.063   Neutral
# 4  Sat Jun 20 04:47:19 PDT 2009  NO_QUERY  2251857687     16.625   Neutral
#
#    target                                               text  \
# 0       0  @CuzImSOOOCool - I haven't been watching baske...
# 1       0           I'm freakin the fuck out maaannn.......
# 2       0      @AlehM ahnem  prefiro house e grey's anatomy!
# 3       0  Im disappointed in the iphone update. It added...
# 4       0         =-surfing net. want to eat chocolates!!!!
#
#                     updated_at            user
# 0  2024-08-25T14:34:09.025334Z  MissSunshine88
# 1  2024-08-25T14:34:07.189764Z        kscerini
# 2  2024-08-25T14:34:04.178149Z         brunohm
# 3  2024-08-25T14:34:00.211517Z   wecantdrive55
# 4  2024-08-25T14:34:33.544917Z       FaithDiao

# %% [markdown]
# ### Задача 4.
#
# Объедините данные, размеченные вручную, с данными, размеченными на основе правил. Объедините два подмножества размеченных данных в один набор данных, сохранив при этом соответствующую структуру и целостность.

# %%
df4 = pd.concat([df2[['target','id','date','flag','user','text','sentiment']],df3[['target','id','date','flag','user','text','sentiment']]])
df4.head()
# Out:
#          target          id                          date      flag  \
# 245491        0  1982016272  Sun May 31 10:21:24 PDT 2009  NO_QUERY
# 1296813       4  2004292021  Tue Jun 02 07:58:35 PDT 2009  NO_QUERY
# 933244        4  1791741842  Wed May 13 20:58:21 PDT 2009  NO_QUERY
# 1056851       4  1962612424  Fri May 29 11:19:15 PDT 2009  NO_QUERY
# 479004        0  2178728334  Mon Jun 15 08:07:16 PDT 2009  NO_QUERY
#
#                    user                                               text  \
# 245491     britt_mxgirl  Got lyk 2 hours of sleep last night. Couldn't ...
# 1296813      Momodel180                        nephew finally fell asleep
# 933244     nasty_nazzle  Bath. It's amazing how weak in the knees she m...
# 1056851   NerdyChristie                        @DixieConstruct Aw, thanks
# 479004   ChocolateViper  @dhersam she done some work in journalism as f...
#
#         sentiment
# 245491    Neutral
# 1296813   Neutral
# 933244   Positive
# 1056851   Neutral
# 479004    Neutral

# %% [markdown]
# ### Задача 5.
#
# Обучите модель машинного обучения, используя объединенный набор размеченных данных. Разделите датасет на обучающий и тестовый наборы и используйте обучающий набор для обучения модели.

# %%
labeled_title, unlabeled_title = train_test_split(df4, train_size=0.2, random_state=42)

# %%
# Определение функции для обучения модели логистической регрессии на размеченных данных
def train_model(labeled_title):
    # Векторизация текстовых данных с помощью TF-IDF
    vectorizer = TfidfVectorizer()
    X = vectorizer.fit_transform(labeled_title['text'])
    y = labeled_title['sentiment']

    # Обучение модели логистической регрессии на размеченных данных
    model = LogisticRegression()
    model.fit(X, y)

    return model, vectorizer

# %%
# Обучение начальной модели на небольшом наборе 
model, vectorizer = train_model(labeled_title)
# Out:
# c:\Users\spite\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# Использование исходной модели для прогнозирования настроения неразмеченных данных
X_unlabeled = vectorizer.transform(unlabeled_title['text'])
y_unlabeled_predicted = model.predict(X_unlabeled)

# %%
# Вычислить неопределенности или энтропии предсказаний
y_unlabeled_proba = model.predict_proba(X_unlabeled)
uncertainty = -(y_unlabeled_proba * np.log2(y_unlabeled_proba)).sum(axis=1)

# %%
# Выбор 100 наиболее неопределенных точек данных для маркировки человеком
labeled_title_new = unlabeled_title.iloc[uncertainty.argsort()[:100]]
unlabeled_title_new = unlabeled_title.iloc[uncertainty.argsort()[100:]]

# %%
labeled_title_new
# Out:
#          target          id                          date      flag  \
# 1297519       4  2004534819  Tue Jun 02 08:21:05 PDT 2009  NO_QUERY
# 1347988       4  2044764029  Fri Jun 05 09:47:32 PDT 2009  NO_QUERY
# 1401424       4  2054546781  Sat Jun 06 07:35:16 PDT 2009  NO_QUERY
# 1529785       4  2177641348  Mon Jun 15 06:27:28 PDT 2009  NO_QUERY
# 944864        4  1795754655  Thu May 14 08:18:50 PDT 2009  NO_QUERY
# ...         ...         ...                           ...       ...
# 1408519       4  2055710455  Sat Jun 06 09:48:56 PDT 2009  NO_QUERY
# 1048104       4  1958114081  Fri May 29 02:42:30 PDT 2009  NO_QUERY
# 924356        4  1754967710  Sun May 10 07:54:03 PDT 2009  NO_QUERY
# 1348347       4  2044847215  Fri Jun 05 09:54:00 PDT 2009  NO_QUERY
# 1111464       4  1972228046  Sat May 30 08:49:27 PDT 2009  NO_QUERY
#
#                     user                                               text  \
# 1297519           Iren19               @tashatwilight  good  love Scorpios
# 1347988  xoxoSuperSaiyan                                 Good morning love
# 1401424           Meader                  @CassieNorrish Good Morning Love
# 1529785    ZakiyaRashida                          @kholi good morning love
# 944864    mlisaoverdrive                        @red_lotus great  I love it
# ...                  ...                                                ...
# 1408519          BombSqd                         Life's good and I'm happy
# 1048104  Literature_Girl                                I love to love you
# 924356       KacieGorman  Good morning and Happy mothers day ! i love my...
# 1348347         COSICols        @Mom2HalfDozen Great, that's good to know!
# 1111464    TobyWanKenoby                         @mayraBELLAlove you good?
#
#         sentiment
# 1297519  Positive
# 1347988  Positive
# 1401424  Positive
# 1529785  Positive
# 944864   Positive
# ...           ...
# 1408519  Positive
# 1048104  Positive
# 924356   Positive
# 1348347  Positive
# 1111464  Positive
#
# [100 rows x 7 columns]

# %%
# Разметка новых точек данных и добавление их к размеченному множеству
labeled_title = pd.concat([labeled_title, labeled_title_new])

# %%
labeled_title.shape
# Out:
# (320120, 7)

# %%
unlabeled_title_new.shape
# Out:
# (1279980, 7)

# %%
# Переобучение модели на расширенном маркированном множестве
model, vectorizer = train_model(labeled_title)
# Out:
# c:\Users\spite\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# ### Задача 6.
#
# Оценить эффективность обученной модели на тестовом датасете. Используйте подходящие метрики оценки. Интерпретируйте результаты и проанализируйте эффективность модели в решении задачи разметки.

# %%
df6 = df.copy()
df6['target'] = df['target'].replace({0: 'Negative', 2: 'Neutral', 4: 'Positive'})
df6.head()
# Out:
#      target          id                          date      flag  \
# 0  Negative  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1  Negative  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2  Negative  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3  Negative  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4  Negative  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
#
#               user                                               text
# 0  _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1    scotthamilton  is upset that he can't update his Facebook by ...
# 2         mattycus  @Kenichan I dived many times for the ball. Man...
# 3          ElleCTF    my whole body feels itchy and like its on fire
# 4           Karoli  @nationwideclass no, it's not behaving at all....

# %%
# Оценка модели на тестовом датасете
X_test = vectorizer.transform(df6['text'])
y_test_predicted = model.predict(X_test)
f1 = f1_score(df6['target'], y_test_predicted, average='micro')

print(f1)
# Out:
# 0.141839375
